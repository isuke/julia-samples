# %%
using PyPlot
PyPlot.svg(true)
# Out:
# true

# %%
x = 1:100
y = [i^2 for i in x]
p = plot(x, y)
xlabel("x")
ylabel("y")
title("Basic plot")
grid("on")
# Out:
# Figure(PyObject <Figure size 640x480 with 1 Axes>)

# %%
# TODO
# x = range(0, stop = 3pi, length = 1000)
# y = cos(2x + 3sin.(3x))
# plot(x, y, color = "orange", linewidth = 2.0, linestyle = "--")
# title("Another plot using sine and cosine")
